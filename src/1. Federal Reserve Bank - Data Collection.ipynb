# %% [markdown]
# # Federal Reserve Bank - Data Collection
#
# <b> Author: </b> Derek A Maier | maierd@canisius.edu
#
# <hr>
#
# ## Scope:
#
# The scope of this workbook includes the following:
#
# - Data Collection from the Federal Reserve data site
# - Data Manipulation / Cleansing for Analysis
# - Storage of the data collection above
#
# <hr>
#
# ## Assumptions:
#
# The development and execution of this workbook / analysis is based on the following assumptions (<i>check marks indicate the assumption has been met</i>):
#
# - <b> ✓ </b> Ethical ability to scrape the FRB Site
# - <b> ✓ </b> Data Availability of Company data for prior two years
#
# <hr>
#
# ## References:
#
# The data was provided by the following base site: https://www.federalreserve.gov/releases/lbr/
#
# <hr>

# %% [markdown]
# ## 1.a. Import Libraries & Set Global Variables

# %%
# Imports
import os
import pickle
import pandas as pd
from datetime import datetime

from dam.scrape import Engine # NOTE: This is a custom package I created for ethical hacking, simply replace with a GET request

# %%
# Global variables
data_dir = 'data/'
data_file = os.path.join(data_dir, 'commercial_bank_data.xlsx')
base_url = "https://www.federalreserve.gov/releases/lbr/"

# %% [markdown]
# ## 1.b. Utility Functions to Parse the FRB Site(s)

# %%
# Create all utility functions for parsing the FRB Soup Objects

# Step 1. Gather all date specific page URLs
def parse_base(url):

    """
    Description:
    ------------
    Parses all of individual date specific links & reports for the data collection step
    
    Params:
    ------------
    url : (str)
        Represents the base url to scrape, or defaults to the static URL
        
    Returns
    ------------
    data : (list)
        Represents a list of dictionaries with the URL and Date of the report 
    
    """
     
    data = None    
    engine = Engine()
    
    try:
        soup = engine.soup_request(url)
        main_div = soup.find("div", attrs={"id": "content"}) # Main container is second out of three
        data = [base_url + val for val in [node["href"] for node in main_div.find_all("a")][2:-1] if val.split('.')[1] == 'htm']
        
    except:
        pass
    
    return data


# Step 2. Parse the Date specific Sites
def parse_data(url):
    
    """
    Description:
    ------------
    Parses all of commercial bank table data from the quarter specific URL site
    
    Params:
    ------------
    url : (str)
        Represents the base url to scrape, or defaults to the static URL
        
    Returns
    ------------
    data : (list)
        Represents a list of dicts with all data collected from the given URL site
    
    """
    
    data = []    
    engine = Engine()
    
    try:
        soup = engine.soup_request(url)
        table = soup.find_all('table')[1] # Main table with data
        trs = table.find_all("tr")[1:]

        for i in range(len(trs)):
            data.append({
                'bank_holding_name': trs[i].find_all("td")[0].text,
                'national_rank': trs[i].find_all("td")[1].text,
                'bank_id': trs[i].find_all("td")[2].text,
                'bank_location': trs[i].find_all("td")[3].text,
                'charter': trs[i].find_all("td")[4].text,
                'consolidated_assets': trs[i].find_all("td")[5].text,
                'domestic_assets': trs[i].find_all("td")[6].text,
                'pct_domestic_assets': trs[i].find_all("td")[7].text,
                'pct_cumulative_assets': trs[i].find_all("td")[8].text,
                'no_domestic_branches': trs[i].find_all("td")[9].text,
                'no_foreign_branches': trs[i].find_all("td")[10].text,
                'ibf': trs[i].find_all("td")[11].text,
                'as_of_dt': url.split('/')[-2].replace('current', '20200331').strip()
            })
        
    except:
        pass
    
    return data

# %% [markdown]
# ## 1.c. Gather & Dump the Base URL Page Links

# %%
# Set links to scrape to a variable using our utility function
links_to_scrape = parse_base(base_url)

# %%
links_to_scrape
# Out:
# ['https://www.federalreserve.gov/releases/lbr/current/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20191231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20190930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20190630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20190331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20181231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20180930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20180630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20180331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20171231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20170930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20170630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20170331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20161231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20160930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20160630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20160331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20151231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20150930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20150630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20150331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20141231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20140930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20140630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20140331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20131231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20130930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20130630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20130331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20121231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20120930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20120630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20120331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20111231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20110930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20110630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20110331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20101231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20100930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20100630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20100331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20091231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20090930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20090630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20090331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20081231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20080930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20080630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20080331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20071231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20070930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20070630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20070331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20061231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20060930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20060630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20060331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20051231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20050930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20050630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20050331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20041231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20040930/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20040630/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20040331/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20031231/default.htm',
#  'https://www.federalreserve.gov/releases/lbr/20030930/default.htm']

# %% [markdown]
# ## 1.d. Scrape all Links above and Store Results

# %%
# Create an empty list to store all results to 
commercial_data = []

for idx, url in enumerate(links_to_scrape):
    print(f'Collecting Data for Link No. {idx}')
    commercial_data += parse_data(url)
# Out:
# Collecting Data for Link No. 0
# Collecting Data for Link No. 1
# Collecting Data for Link No. 2
# Collecting Data for Link No. 3
# Collecting Data for Link No. 4
# Collecting Data for Link No. 5
# Collecting Data for Link No. 6
# Collecting Data for Link No. 7
# Collecting Data for Link No. 8
# Collecting Data for Link No. 9
# Collecting Data for Link No. 10
# Collecting Data for Link No. 11
# Collecting Data for Link No. 12
# Collecting Data for Link No. 13
# Collecting Data for Link No. 14
# Collecting Data for Link No. 15
# Collecting Data for Link No. 16
# Collecting Data for Link No. 17
# Collecting Data for Link No. 18
# Collecting Data for Link No. 19
# Collecting Data for Link No. 20
# Collecting Data for Link No. 21
# Collecting Data for Link No. 22
# Collecting Data for Link No. 23
# Collecting Data for Link No. 24
# Collecting Data for Link No. 25
# Collecting Data for Link No. 26
# Collecting Data for Link No. 27
# Collecting Data for Link No. 28
# Collecting Data for Link No. 29
# Collecting Data for Link No. 30
# Collecting Data for Link No. 31
# Collecting Data for Link No. 32
# Collecting Data for Link No. 33
# Collecting Data for Link No. 34
# Collecting Data for Link No. 35
# Collecting Data for Link No. 36
# Collecting Data for Link No. 37
# Collecting Data for Link No. 38
# Collecting Data for Link No. 39
# Collecting Data for Link No. 40
# Collecting Data for Link No. 41
# Collecting Data for Link No. 42
# Collecting Data for Link No. 43
# Collecting Data for Link No. 44
# Collecting Data for Link No. 45
# Collecting Data for Link No. 46
# Collecting Data for Link No. 47
# Collecting Data for Link No. 48
# Collecting Data for Link No. 49
# Collecting Data for Link No. 50
# Collecting Data for Link No. 51
# Collecting Data for Link No. 52
# Collecting Data for Link No. 53
# Collecting Data for Link No. 54
# Collecting Data for Link No. 55
# Collecting Data for Link No. 56
# Collecting Data for Link No. 57
# Collecting Data for Link No. 58
# Collecting Data for Link No. 59
# Collecting Data for Link No. 60
# Collecting Data for Link No. 61
# Collecting Data for Link No. 62
# Collecting Data for Link No. 63
# Collecting Data for Link No. 64
# Collecting Data for Link No. 65
# Collecting Data for Link No. 66

# %%
print(f'The total number of records returned for our dataset : {len(commercial_data)}')
print("="*70)
commercial_data
# Out:
# The total number of records returned for our dataset : 98354
# ======================================================================
# [{'bank_holding_name': 'JPMORGAN CHASE BK NA/JPMORGAN CHASE & CO ',
#   'national_rank': '1 ',
#   'bank_id': '852218 ',
#   'bank_location': 'COLUMBUS, OH ',
#   'charter': 'NAT ',
#   'consolidated_assets': '2,690,959 ',
#   'domestic_assets': '1,990,017 ',
#   'pct_domestic_assets': '74 ',
#   'pct_cumulative_assets': '15 ',
#   'no_domestic_branches': '4,971 ',
#   'no_foreign_branches': '33 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF AMER NA/BANK OF AMER CORP ',
#   'national_rank': '2 ',
#   'bank_id': '480228 ',
#   'bank_location': 'CHARLOTTE, NC ',
#   'charter': 'NAT ',
#   'consolidated_assets': '2,031,940 ',
#   'domestic_assets': '1,925,005 ',
#   'pct_domestic_assets': '95 ',
#   'pct_cumulative_assets': '26 ',
#   'no_domestic_branches': '4,239 ',
#   'no_foreign_branches': '26 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WELLS FARGO BK NA/WELLS FARGO & CO ',
#   'national_rank': '3 ',
#   'bank_id': '451965 ',
#   'bank_location': 'SIOUX FALLS, SD ',
#   'charter': 'NAT ',
#   'consolidated_assets': '1,763,696 ',
#   'domestic_assets': '1,715,842 ',
#   'pct_domestic_assets': '97 ',
#   'pct_cumulative_assets': '35 ',
#   'no_domestic_branches': '5,416 ',
#   'no_foreign_branches': '11 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIBANK NA/CITIGROUP ',
#   'national_rank': '4 ',
#   'bank_id': '476810 ',
#   'bank_location': 'SIOUX FALLS, SD ',
#   'charter': 'NAT ',
#   'consolidated_assets': '1,632,405 ',
#   'domestic_assets': '971,079 ',
#   'pct_domestic_assets': '59 ',
#   'pct_cumulative_assets': '44 ',
#   'no_domestic_branches': '697 ',
#   'no_foreign_branches': '157 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'U S BK NA/U S BC ',
#   'national_rank': '5 ',
#   'bank_id': '504713 ',
#   'bank_location': 'CINCINNATI, OH ',
#   'charter': 'NAT ',
#   'consolidated_assets': '533,129 ',
#   'domestic_assets': '522,496 ',
#   'pct_domestic_assets': '98 ',
#   'pct_cumulative_assets': '47 ',
#   'no_domestic_branches': '2,832 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TRUIST BK/TRUIST FC ',
#   'national_rank': '6 ',
#   'bank_id': '852320 ',
#   'bank_location': 'CHARLOTTE, NC ',
#   'charter': 'SNM ',
#   'consolidated_assets': '495,079 ',
#   'domestic_assets': '494,996 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '50 ',
#   'no_domestic_branches': '2,959 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PNC BK NA/PNC FNCL SVC GROUP ',
#   'national_rank': '7 ',
#   'bank_id': '817824 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'NAT ',
#   'consolidated_assets': '433,803 ',
#   'domestic_assets': '429,087 ',
#   'pct_domestic_assets': '99 ',
#   'pct_cumulative_assets': '52 ',
#   'no_domestic_branches': '2,341 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF NY MELLON/BANK OF NY MELLON CORP ',
#   'national_rank': '8 ',
#   'bank_id': '541101 ',
#   'bank_location': 'NEW YORK, NY ',
#   'charter': 'SMB ',
#   'consolidated_assets': '387,037 ',
#   'domestic_assets': '254,569 ',
#   'pct_domestic_assets': '66 ',
#   'pct_cumulative_assets': '54 ',
#   'no_domestic_branches': '2 ',
#   'no_foreign_branches': '14 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'STATE STREET B&TC/STATE STREET CORP ',
#   'national_rank': '9 ',
#   'bank_id': '35301 ',
#   'bank_location': 'BOSTON, MA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '359,196 ',
#   'domestic_assets': '253,669 ',
#   'pct_domestic_assets': '71 ',
#   'pct_cumulative_assets': '56 ',
#   'no_domestic_branches': '2 ',
#   'no_foreign_branches': '10 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'T D BK NA/TD GRP US HOLDS LLC ',
#   'national_rank': '10 ',
#   'bank_id': '497404 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'NAT ',
#   'consolidated_assets': '355,768 ',
#   'domestic_assets': '355,768 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '58 ',
#   'no_domestic_branches': '1,224 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CAPITAL ONE NA/CAPITAL ONE FC ',
#   'national_rank': '11 ',
#   'bank_id': '112837 ',
#   'bank_location': 'MC LEAN, VA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '339,216 ',
#   'domestic_assets': '339,213 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '60 ',
#   'no_domestic_branches': '467 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'GOLDMAN SACHS BK USA/GOLDMAN SACHS GROUP THE ',
#   'national_rank': '12 ',
#   'bank_id': '2182786 ',
#   'bank_location': 'NEW YORK, NY ',
#   'charter': 'SMB ',
#   'consolidated_assets': '254,668 ',
#   'domestic_assets': '254,668 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '61 ',
#   'no_domestic_branches': '2 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'HSBC BK USA NA/HSBC N AMER HOLDS ',
#   'national_rank': '13 ',
#   'bank_id': '413208 ',
#   'bank_location': 'TYSONS, VA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '201,886 ',
#   'domestic_assets': '200,925 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '62 ',
#   'no_domestic_branches': '224 ',
#   'no_foreign_branches': '3 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIFTH THIRD BK NA/FIFTH THIRD BC ',
#   'national_rank': '14 ',
#   'bank_id': '723112 ',
#   'bank_location': 'CINCINNATI, OH ',
#   'charter': 'NAT ',
#   'consolidated_assets': '183,724 ',
#   'domestic_assets': '183,121 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '63 ',
#   'no_domestic_branches': '1,143 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MORGAN STANLEY BK NA/MORGAN STANLEY ',
#   'national_rank': '15 ',
#   'bank_id': '1456501 ',
#   'bank_location': 'SALT LAKE CITY, UT ',
#   'charter': 'NAT ',
#   'consolidated_assets': '178,664 ',
#   'domestic_assets': '178,664 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '64 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIZENS BK NA/CITIZENS FNCL GRP ',
#   'national_rank': '16 ',
#   'bank_id': '3303298 ',
#   'bank_location': 'PROVIDENCE, RI ',
#   'charter': 'NAT ',
#   'consolidated_assets': '176,633 ',
#   'domestic_assets': '176,633 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '65 ',
#   'no_domestic_branches': '1,049 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ALLY BK/ALLY FNCL ',
#   'national_rank': '17 ',
#   'bank_id': '3284070 ',
#   'bank_location': 'SANDY, UT ',
#   'charter': 'SMB ',
#   'consolidated_assets': '170,655 ',
#   'domestic_assets': '170,655 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '66 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'NORTHERN TC/NORTHERN TR CORP ',
#   'national_rank': '18 ',
#   'bank_id': '210434 ',
#   'bank_location': 'CHICAGO, IL ',
#   'charter': 'SMB ',
#   'consolidated_assets': '161,164 ',
#   'domestic_assets': '109,110 ',
#   'pct_domestic_assets': '68 ',
#   'pct_cumulative_assets': '67 ',
#   'no_domestic_branches': '55 ',
#   'no_foreign_branches': '5 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'KEYBANK NA/KEYCORP ',
#   'national_rank': '19 ',
#   'bank_id': '280110 ',
#   'bank_location': 'CLEVELAND, OH ',
#   'charter': 'NAT ',
#   'consolidated_assets': '154,994 ',
#   'domestic_assets': '154,980 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '68 ',
#   'no_domestic_branches': '1,103 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BMO HARRIS BK NA/BMO FNCL CORP ',
#   'national_rank': '20 ',
#   'bank_id': '75633 ',
#   'bank_location': 'CHICAGO, IL ',
#   'charter': 'NAT ',
#   'consolidated_assets': '145,169 ',
#   'domestic_assets': '145,169 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '69 ',
#   'no_domestic_branches': '567 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MUFG UNION BK NA/MUFG AMERS HOLDS CORP ',
#   'national_rank': '21 ',
#   'bank_id': '212465 ',
#   'bank_location': 'SAN FRANCISCO, CA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '135,038 ',
#   'domestic_assets': '135,038 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '69 ',
#   'no_domestic_branches': '347 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'REGIONS BK/REGIONS FC ',
#   'national_rank': '22 ',
#   'bank_id': '233031 ',
#   'bank_location': 'BIRMINGHAM, AL ',
#   'charter': 'SMB ',
#   'consolidated_assets': '132,707 ',
#   'domestic_assets': '132,707 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '70 ',
#   'no_domestic_branches': '1,427 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'AMERICAN EXPRESS NB/AMERICAN EXPRESS CO ',
#   'national_rank': '23 ',
#   'bank_id': '1394676 ',
#   'bank_location': 'SANDY, UT ',
#   'charter': 'NAT ',
#   'consolidated_assets': '130,004 ',
#   'domestic_assets': '130,004 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '71 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MANUFACTURERS & TRADERS TC/M&T BK CORP ',
#   'national_rank': '24 ',
#   'bank_id': '501105 ',
#   'bank_location': 'BUFFALO, NY ',
#   'charter': 'SMB ',
#   'consolidated_assets': '124,147 ',
#   'domestic_assets': '124,147 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '71 ',
#   'no_domestic_branches': '766 ',
#   'no_foreign_branches': '2 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST REPUBLIC BK/ ',
#   'national_rank': '25 ',
#   'bank_id': '4114567 ',
#   'bank_location': 'SAN FRANCISCO, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '123,915 ',
#   'domestic_assets': '123,915 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '72 ',
#   'no_domestic_branches': '72 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CAPITAL ONE BK USA NA/CAPITAL ONE FC ',
#   'national_rank': '26 ',
#   'bank_id': '2253891 ',
#   'bank_location': 'GLEN ALLEN, VA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '116,772 ',
#   'domestic_assets': '116,061 ',
#   'pct_domestic_assets': '99 ',
#   'pct_cumulative_assets': '73 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'HUNTINGTON NB/HUNTINGTON BSHRS ',
#   'national_rank': '27 ',
#   'bank_id': '12311 ',
#   'bank_location': 'COLUMBUS, OH ',
#   'charter': 'NAT ',
#   'consolidated_assets': '113,764 ',
#   'domestic_assets': '113,764 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '73 ',
#   'no_domestic_branches': '885 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'DISCOVER BK/DISCOVER FS ',
#   'national_rank': '28 ',
#   'bank_id': '30810 ',
#   'bank_location': 'GREENWOOD, DE ',
#   'charter': 'SNM ',
#   'consolidated_assets': '111,140 ',
#   'domestic_assets': '111,140 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '74 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MORGAN STANLEY PRIV BK NA/MORGAN STANLEY ',
#   'national_rank': '29 ',
#   'bank_id': '2489805 ',
#   'bank_location': 'PURCHASE, NY ',
#   'charter': 'NAT ',
#   'consolidated_assets': '106,390 ',
#   'domestic_assets': '106,390 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '75 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF THE WEST/BNP PARIBAS USA ',
#   'national_rank': '30 ',
#   'bank_id': '804963 ',
#   'bank_location': 'SAN FRANCISCO, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '101,372 ',
#   'domestic_assets': '101,372 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '75 ',
#   'no_domestic_branches': '551 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BBVA USA/BBVA USA BSHRS ',
#   'national_rank': '31 ',
#   'bank_id': '697633 ',
#   'bank_location': 'BIRMINGHAM, AL ',
#   'charter': 'SMB ',
#   'consolidated_assets': '93,020 ',
#   'domestic_assets': '93,020 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '76 ',
#   'no_domestic_branches': '640 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SANTANDER BK NA/SANTANDER HOLDS USA ',
#   'national_rank': '32 ',
#   'bank_id': '722777 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'NAT ',
#   'consolidated_assets': '87,569 ',
#   'domestic_assets': '87,567 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '76 ',
#   'no_domestic_branches': '585 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COMERICA BK/COMERICA ',
#   'national_rank': '33 ',
#   'bank_id': '60143 ',
#   'bank_location': 'DALLAS, TX ',
#   'charter': 'SMB ',
#   'consolidated_assets': '76,262 ',
#   'domestic_assets': '75,759 ',
#   'pct_domestic_assets': '99 ',
#   'pct_cumulative_assets': '77 ',
#   'no_domestic_branches': '435 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SILICON VALLEY BK/SVB FNCL GRP ',
#   'national_rank': '34 ',
#   'bank_id': '802866 ',
#   'bank_location': 'SANTA CLARA, CA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '73,632 ',
#   'domestic_assets': '69,040 ',
#   'pct_domestic_assets': '94 ',
#   'pct_cumulative_assets': '77 ',
#   'no_domestic_branches': '4 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ZIONS BC NA/ ',
#   'national_rank': '35 ',
#   'bank_id': '276579 ',
#   'bank_location': 'SALT LAKE CITY, UT ',
#   'charter': 'NAT ',
#   'consolidated_assets': '71,467 ',
#   'domestic_assets': '71,467 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '77 ',
#   'no_domestic_branches': '425 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITY NB/RBC US GRP HOLDS LLC ',
#   'national_rank': '36 ',
#   'bank_id': '63069 ',
#   'bank_location': 'LOS ANGELES, CA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '65,955 ',
#   'domestic_assets': '65,955 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '78 ',
#   'no_domestic_branches': '72 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PEOPLES UNITED BK NA/PEOPLES UNITED FNCL INC ',
#   'national_rank': '37 ',
#   'bank_id': '613307 ',
#   'bank_location': 'BRIDGEPORT, CT ',
#   'charter': 'NAT ',
#   'consolidated_assets': '60,207 ',
#   'domestic_assets': '60,207 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '78 ',
#   'no_domestic_branches': '442 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SIGNATURE BK/ ',
#   'national_rank': '38 ',
#   'bank_id': '2942690 ',
#   'bank_location': 'NEW YORK, NY ',
#   'charter': 'SNM ',
#   'consolidated_assets': '53,075 ',
#   'domestic_assets': '53,075 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '78 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CIT BK NA/CIT GROUP ',
#   'national_rank': '39 ',
#   'bank_id': '3918898 ',
#   'bank_location': 'PASADENA, CA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '52,993 ',
#   'domestic_assets': '52,993 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '79 ',
#   'no_domestic_branches': '88 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SYNOVUS BK/SYNOVUS FC ',
#   'national_rank': '40 ',
#   'bank_id': '395238 ',
#   'bank_location': 'COLUMBUS, GA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '50,522 ',
#   'domestic_assets': '50,522 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '79 ',
#   'no_domestic_branches': '299 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TCF NB/TCF FC ',
#   'national_rank': '41 ',
#   'bank_id': '266271 ',
#   'bank_location': 'SIOUX FALLS, SD ',
#   'charter': 'NAT ',
#   'consolidated_assets': '48,563 ',
#   'domestic_assets': '48,293 ',
#   'pct_domestic_assets': '99 ',
#   'pct_cumulative_assets': '79 ',
#   'no_domestic_branches': '516 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST HORIZON BK/FIRST HORIZON NAT CORP ',
#   'national_rank': '42 ',
#   'bank_id': '485559 ',
#   'bank_location': 'MEMPHIS, TN ',
#   'charter': 'SMB ',
#   'consolidated_assets': '47,026 ',
#   'domestic_assets': '47,026 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '79 ',
#   'no_domestic_branches': '273 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BOKF NA/BOK FC ',
#   'national_rank': '43 ',
#   'bank_id': '339858 ',
#   'bank_location': 'TULSA, OK ',
#   'charter': 'NAT ',
#   'consolidated_assets': '46,955 ',
#   'domestic_assets': '46,955 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '80 ',
#   'no_domestic_branches': '124 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'EAST WEST BK/EAST WEST BC ',
#   'national_rank': '44 ',
#   'bank_id': '197478 ',
#   'bank_location': 'PASADENA, CA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '45,939 ',
#   'domestic_assets': '43,748 ',
#   'pct_domestic_assets': '95 ',
#   'pct_cumulative_assets': '80 ',
#   'no_domestic_branches': '109 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'DEUTSCHE BK TC AMERICAS/DB USA CORP ',
#   'national_rank': '45 ',
#   'bank_id': '214807 ',
#   'bank_location': 'NEW YORK, NY ',
#   'charter': 'SMB ',
#   'consolidated_assets': '41,537 ',
#   'domestic_assets': '41,537 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '80 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST-CITIZENS B&TC/FIRST CITIZENS BSHRS ',
#   'national_rank': '46 ',
#   'bank_id': '491224 ',
#   'bank_location': 'RALEIGH, NC ',
#   'charter': 'SNM ',
#   'consolidated_assets': '41,377 ',
#   'domestic_assets': '41,377 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '80 ',
#   'no_domestic_branches': '574 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'VALLEY NB/VALLEY NAT BC ',
#   'national_rank': '47 ',
#   'bank_id': '229801 ',
#   'bank_location': 'PASSAIC, NJ ',
#   'charter': 'NAT ',
#   'consolidated_assets': '39,109 ',
#   'domestic_assets': '39,109 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '235 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TEXAS CAP BK NA/TEXAS CAP BSHRS ',
#   'national_rank': '48 ',
#   'bank_id': '2618780 ',
#   'bank_location': 'DALLAS, TX ',
#   'charter': 'NAT ',
#   'consolidated_assets': '35,848 ',
#   'domestic_assets': '35,848 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '11 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CIBC BK USA/CIBC BC USA ',
#   'national_rank': '49 ',
#   'bank_id': '1842065 ',
#   'bank_location': 'CHICAGO, IL ',
#   'charter': 'SNM ',
#   'consolidated_assets': '35,548 ',
#   'domestic_assets': '35,548 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '22 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST NB OF PA/FNB CORP ',
#   'national_rank': '50 ',
#   'bank_id': '379920 ',
#   'bank_location': 'GREENVILLE, PA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '35,015 ',
#   'domestic_assets': '35,015 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '368 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FROST BK/CULLEN/FROST BKR ',
#   'national_rank': '51 ',
#   'bank_id': '682563 ',
#   'bank_location': 'SAN ANTONIO, TX ',
#   'charter': 'SMB ',
#   'consolidated_assets': '34,249 ',
#   'domestic_assets': '34,249 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '155 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ASSOCIATED BK NA/ASSOCIATED BANC-CORP ',
#   'national_rank': '52 ',
#   'bank_id': '917742 ',
#   'bank_location': 'GREEN BAY, WI ',
#   'charter': 'NAT ',
#   'consolidated_assets': '33,859 ',
#   'domestic_assets': '33,859 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '81 ',
#   'no_domestic_branches': '256 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'RAYMOND JAMES BK NA/RAYMOND JAMES FNCL ',
#   'national_rank': '53 ',
#   'bank_id': '2193616 ',
#   'bank_location': 'SAINT PETERSBURG, FL ',
#   'charter': 'NAT ',
#   'consolidated_assets': '33,656 ',
#   'domestic_assets': '33,457 ',
#   'pct_domestic_assets': '99 ',
#   'pct_cumulative_assets': '82 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANKUNITED NA/BANKUNITED ',
#   'national_rank': '54 ',
#   'bank_id': '3938186 ',
#   'bank_location': 'MIAMI LAKES, FL ',
#   'charter': 'NAT ',
#   'consolidated_assets': '33,512 ',
#   'domestic_assets': '33,512 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '82 ',
#   'no_domestic_branches': '79 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BARCLAYS BK DE/BARCLAYS US LLC ',
#   'national_rank': '55 ',
#   'bank_id': '2980209 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'SNM ',
#   'consolidated_assets': '33,430 ',
#   'domestic_assets': '33,430 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '82 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'IBERIABANK/IBERIABANK CORP ',
#   'national_rank': '56 ',
#   'bank_id': '808176 ',
#   'bank_location': 'LAFAYETTE, LA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '32,147 ',
#   'domestic_assets': '32,147 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '82 ',
#   'no_domestic_branches': '191 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'HANCOCK WHITNEY BK/HANCOCK WHITNEY CORP ',
#   'national_rank': '57 ',
#   'bank_id': '463735 ',
#   'bank_location': 'GULFPORT, MS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '31,746 ',
#   'domestic_assets': '31,746 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '82 ',
#   'no_domestic_branches': '215 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PROSPERITY BK/PROSPERITY BSHRS ',
#   'national_rank': '58 ',
#   'bank_id': '664756 ',
#   'bank_location': 'EL CAMPO, TX ',
#   'charter': 'SNM ',
#   'consolidated_assets': '31,744 ',
#   'domestic_assets': '31,744 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '304 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WEBSTER BK NA/WEBSTER FNCL CORP ',
#   'national_rank': '59 ',
#   'bank_id': '761806 ',
#   'bank_location': 'WATERBURY, CT ',
#   'charter': 'NAT ',
#   'consolidated_assets': '31,658 ',
#   'domestic_assets': '31,658 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '156 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BNY MELLON NA/BANK OF NY MELLON CORP ',
#   'national_rank': '60 ',
#   'bank_id': '934329 ',
#   'bank_location': 'PITTSBURGH, PA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '31,061 ',
#   'domestic_assets': '31,061 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '1 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'STERLING NB/STERLING BC ',
#   'national_rank': '61 ',
#   'bank_id': '125471 ',
#   'bank_location': 'MONTEBELLO, NY ',
#   'charter': 'NAT ',
#   'consolidated_assets': '30,259 ',
#   'domestic_assets': '30,259 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '79 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WESTERN ALLI BK/WESTERN ALLI BC ',
#   'national_rank': '62 ',
#   'bank_id': '3138146 ',
#   'bank_location': 'PHOENIX, AZ ',
#   'charter': 'SMB ',
#   'consolidated_assets': '29,191 ',
#   'domestic_assets': '29,191 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '38 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PINNACLE BK/PINNACLE FNCL PTNR ',
#   'national_rank': '63 ',
#   'bank_id': '2925666 ',
#   'bank_location': 'NASHVILLE, TN ',
#   'charter': 'SNM ',
#   'consolidated_assets': '29,127 ',
#   'domestic_assets': '29,127 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '110 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'UMPQUA BK/UMPQUA HC ',
#   'national_rank': '64 ',
#   'bank_id': '143662 ',
#   'bank_location': 'ROSEBURG, OR ',
#   'charter': 'SNM ',
#   'consolidated_assets': '27,511 ',
#   'domestic_assets': '27,511 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '83 ',
#   'no_domestic_branches': '240 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'T D BK USA NA/TD GRP US HOLDS LLC ',
#   'national_rank': '65 ',
#   'bank_id': '2121196 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'NAT ',
#   'consolidated_assets': '27,042 ',
#   'domestic_assets': '27,042 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '1 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COMMERCE BK/COMMERCE BSHRS ',
#   'national_rank': '66 ',
#   'bank_id': '601050 ',
#   'bank_location': 'KANSAS CITY, MO ',
#   'charter': 'SMB ',
#   'consolidated_assets': '26,700 ',
#   'domestic_assets': '26,700 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '163 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'INVESTORS BK/INVESTORS BC ',
#   'national_rank': '67 ',
#   'bank_id': '35570 ',
#   'bank_location': 'SHORT HILLS, NJ ',
#   'charter': 'SNM ',
#   'consolidated_assets': '26,670 ',
#   'domestic_assets': '26,670 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '146 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'UMB BK NA/UMB FC ',
#   'national_rank': '68 ',
#   'bank_id': '936855 ',
#   'bank_location': 'KANSAS CITY, MO ',
#   'charter': 'NAT ',
#   'consolidated_assets': '26,151 ',
#   'domestic_assets': '26,151 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '93 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PACIFIC WESTERN BK/PACWEST BC ',
#   'national_rank': '69 ',
#   'bank_id': '494261 ',
#   'bank_location': 'BEVERLY HILLS, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '26,100 ',
#   'domestic_assets': '26,100 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '75 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WELLS FARGO NB WEST/WELLS FARGO & CO ',
#   'national_rank': '70 ',
#   'bank_id': '1225761 ',
#   'bank_location': 'LAS VEGAS, NV ',
#   'charter': 'NAT ',
#   'consolidated_assets': '25,855 ',
#   'domestic_assets': '25,855 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OZK/ ',
#   'national_rank': '71 ',
#   'bank_id': '107244 ',
#   'bank_location': 'LITTLE ROCK, AR ',
#   'charter': 'SNM ',
#   'consolidated_assets': '24,566 ',
#   'domestic_assets': '24,566 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '84 ',
#   'no_domestic_branches': '238 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FULTON BK NA/FULTON FNCL CORP ',
#   'national_rank': '72 ',
#   'bank_id': '474919 ',
#   'bank_location': 'LANCASTER, PA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '22,781 ',
#   'domestic_assets': '22,781 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '230 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST NB OF OMAHA/LAURITZEN CORP ',
#   'national_rank': '73 ',
#   'bank_id': '527954 ',
#   'bank_location': 'OMAHA, NE ',
#   'charter': 'NAT ',
#   'consolidated_assets': '22,265 ',
#   'domestic_assets': '22,265 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '122 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANCORPSOUTH BK/ ',
#   'national_rank': '74 ',
#   'bank_id': '606046 ',
#   'bank_location': 'TUPELO, MS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '21,045 ',
#   'domestic_assets': '21,045 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '317 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SIMMONS BK/SIMMONS FIRST NAT CORP ',
#   'national_rank': '75 ',
#   'bank_id': '663245 ',
#   'bank_location': 'PINE BLUFF, AR ',
#   'charter': 'SMB ',
#   'consolidated_assets': '20,796 ',
#   'domestic_assets': '20,796 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '242 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST HAWAIIAN BK/FIRST HAWAIIAN ',
#   'national_rank': '76 ',
#   'bank_id': '980661 ',
#   'bank_location': 'HONOLULU, HI ',
#   'charter': 'SNM ',
#   'consolidated_assets': '20,756 ',
#   'domestic_assets': '20,050 ',
#   'pct_domestic_assets': '97 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '57 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'OLD NB/OLD NAT BC ',
#   'national_rank': '77 ',
#   'bank_id': '208244 ',
#   'bank_location': 'EVANSVILLE, IN ',
#   'charter': 'NAT ',
#   'consolidated_assets': '20,647 ',
#   'domestic_assets': '20,647 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '194 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ARVEST BK/ARVEST BK GRP ',
#   'national_rank': '78 ',
#   'bank_id': '311845 ',
#   'bank_location': 'FAYETTEVILLE, AR ',
#   'charter': 'SMB ',
#   'consolidated_assets': '20,504 ',
#   'domestic_assets': '20,504 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '275 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'UNITED BK/UNITED BSHRS ',
#   'national_rank': '79 ',
#   'bank_id': '365325 ',
#   'bank_location': 'FAIRFAX, VA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '20,353 ',
#   'domestic_assets': '20,353 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '85 ',
#   'no_domestic_branches': '136 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRSTBANK/FIRSTBANK HC ',
#   'national_rank': '80 ',
#   'bank_id': '288853 ',
#   'bank_location': 'LAKEWOOD, CO ',
#   'charter': 'SMB ',
#   'consolidated_assets': '20,199 ',
#   'domestic_assets': '20,199 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '118 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF AMER CA NA/BANK OF AMER CORP ',
#   'national_rank': '81 ',
#   'bank_id': '1443266 ',
#   'bank_location': 'SAN FRANCISCO, CA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '18,802 ',
#   'domestic_assets': '0 ',
#   'pct_domestic_assets': '0 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST MW BK/FIRST MW BC ',
#   'national_rank': '82 ',
#   'bank_id': '1007846 ',
#   'bank_location': 'CHICAGO, IL ',
#   'charter': 'SMB ',
#   'consolidated_assets': '18,739 ',
#   'domestic_assets': '18,739 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '119 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CENTERSTATE BK NA/CENTERSTATE BK CORP ',
#   'national_rank': '83 ',
#   'bank_id': '1929247 ',
#   'bank_location': 'WINTER HAVEN, FL ',
#   'charter': 'NAT ',
#   'consolidated_assets': '18,591 ',
#   'domestic_assets': '18,591 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '149 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF HAWAII/BANK OF HI CORP ',
#   'national_rank': '84 ',
#   'bank_id': '795968 ',
#   'bank_location': 'HONOLULU, HI ',
#   'charter': 'SMB ',
#   'consolidated_assets': '18,513 ',
#   'domestic_assets': '17,882 ',
#   'pct_domestic_assets': '97 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '67 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'Y ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CATHAY BK/CATHAY GEN BC ',
#   'national_rank': '85 ',
#   'bank_id': '595869 ',
#   'bank_location': 'LOS ANGELES, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '18,265 ',
#   'domestic_assets': '17,807 ',
#   'pct_domestic_assets': '97 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '60 ',
#   'no_foreign_branches': '1 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'AMERIS BK/AMERIS BC ',
#   'national_rank': '86 ',
#   'bank_id': '764030 ',
#   'bank_location': 'ATLANTA, GA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '18,126 ',
#   'domestic_assets': '18,126 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '171 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ATLANTIC UNION BK/ATLANTIC UNION BSHRS CORP ',
#   'national_rank': '87 ',
#   'bank_id': '693224 ',
#   'bank_location': 'RICHMOND, VA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '17,802 ',
#   'domestic_assets': '17,802 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '148 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WASHINGTON FED BK NA/WASHINGTON FED INC ',
#   'national_rank': '88 ',
#   'bank_id': '656377 ',
#   'bank_location': 'SEATTLE, WA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '17,372 ',
#   'domestic_assets': '17,372 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '234 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CADENCE BK NA/CADENCE BC ',
#   'national_rank': '89 ',
#   'bank_id': '4262534 ',
#   'bank_location': 'ATLANTA, GA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '17,233 ',
#   'domestic_assets': '17,233 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '101 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MECHANICS BK/2011 TCRT ',
#   'national_rank': '90 ',
#   'bank_id': '936462 ',
#   'bank_location': 'WALNUT CREEK, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '17,041 ',
#   'domestic_assets': '17,041 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '86 ',
#   'no_domestic_branches': '144 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SOUTH ST BK/SOUTH ST CORP ',
#   'national_rank': '91 ',
#   'bank_id': '540926 ',
#   'bank_location': 'COLUMBIA, SC ',
#   'charter': 'SNM ',
#   'consolidated_assets': '16,639 ',
#   'domestic_assets': '16,639 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '155 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITY NB OF FL/BCI FNCL GRP ',
#   'national_rank': '92 ',
#   'bank_id': '814430 ',
#   'bank_location': 'MIAMI, FL ',
#   'charter': 'NAT ',
#   'consolidated_assets': '16,241 ',
#   'domestic_assets': '16,241 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '31 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANK OF HOPE/HOPE BC ',
#   'national_rank': '93 ',
#   'bank_id': '671464 ',
#   'bank_location': 'LOS ANGELES, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '16,020 ',
#   'domestic_assets': '16,020 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '58 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WESBANCO BK/WESBANCO ',
#   'national_rank': '94 ',
#   'bank_id': '645625 ',
#   'bank_location': 'WHEELING, WV ',
#   'charter': 'SNM ',
#   'consolidated_assets': '15,965 ',
#   'domestic_assets': '15,965 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '235 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'INDEPENDENT BK/INDEPENDENT BK GRP ',
#   'national_rank': '95 ',
#   'bank_id': '122854 ',
#   'bank_location': 'MCKINNEY, TX ',
#   'charter': 'SNM ',
#   'consolidated_assets': '15,569 ',
#   'domestic_assets': '15,569 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '94 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CENTENNIAL BK/HOME BSHRS ',
#   'national_rank': '96 ',
#   'bank_id': '456045 ',
#   'bank_location': 'CONWAY, AR ',
#   'charter': 'SMB ',
#   'consolidated_assets': '15,500 ',
#   'domestic_assets': '15,500 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '166 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'GLACIER BK/GLACIER BC ',
#   'national_rank': '97 ',
#   'bank_id': '2634191 ',
#   'bank_location': 'KALISPELL, MT ',
#   'charter': 'SNM ',
#   'consolidated_assets': '15,147 ',
#   'domestic_assets': '15,147 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '174 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST FNCL BK/FIRST FNCL BC ',
#   'national_rank': '98 ',
#   'bank_id': '165628 ',
#   'bank_location': 'CINCINNATI, OH ',
#   'charter': 'SMB ',
#   'consolidated_assets': '14,987 ',
#   'domestic_assets': '14,987 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '148 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'STIFEL B&T/STIFEL FNCL CORP ',
#   'national_rank': '99 ',
#   'bank_id': '3076248 ',
#   'bank_location': 'SAINT LOUIS, MO ',
#   'charter': 'SMB ',
#   'consolidated_assets': '14,910 ',
#   'domestic_assets': '14,910 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '1 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST INTRST BK/FIRST INTRST BANCSYSTEM ',
#   'national_rank': '100 ',
#   'bank_id': '659855 ',
#   'bank_location': 'BILLINGS, MT ',
#   'charter': 'SMB ',
#   'consolidated_assets': '14,352 ',
#   'domestic_assets': '14,352 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '151 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COLUMBIA ST BK/COLUMBIA BKG SYS ',
#   'national_rank': '101 ',
#   'bank_id': '2078290 ',
#   'bank_location': 'TACOMA, WA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '14,030 ',
#   'domestic_assets': '14,030 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '146 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TRUSTMARK NB/TRUSTMARK CORP ',
#   'national_rank': '102 ',
#   'bank_id': '342634 ',
#   'bank_location': 'JACKSON, MS ',
#   'charter': 'NAT ',
#   'consolidated_assets': '14,018 ',
#   'domestic_assets': '14,018 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '87 ',
#   'no_domestic_branches': '191 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'RENASANT BK/RENASANT CORP ',
#   'national_rank': '103 ',
#   'bank_id': '749242 ',
#   'bank_location': 'TUPELO, MS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '13,874 ',
#   'domestic_assets': '13,874 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '168 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BREMER BK NA/OTTO BREMER TR ',
#   'national_rank': '104 ',
#   'bank_id': '800657 ',
#   'bank_location': 'SAINT PAUL, MN ',
#   'charter': 'NAT ',
#   'consolidated_assets': '13,211 ',
#   'domestic_assets': '13,211 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '78 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BERKSHIRE BK/BERKSHIRE HILLS BC ',
#   'national_rank': '105 ',
#   'bank_id': '473501 ',
#   'bank_location': 'PITTSFIELD, MA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '13,204 ',
#   'domestic_assets': '13,204 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '130 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'UNITED CMNTY BK/UNITED CMNTY BK ',
#   'national_rank': '106 ',
#   'bank_id': '1017939 ',
#   'bank_location': 'BLAIRSVILLE, GA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '13,059 ',
#   'domestic_assets': '13,059 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '141 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST MRCHS BK/FIRST MRCHS CORP ',
#   'national_rank': '107 ',
#   'bank_id': '17147 ',
#   'bank_location': 'MUNCIE, IN ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,670 ',
#   'domestic_assets': '12,670 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '131 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TOWNEBANK/ ',
#   'national_rank': '108 ',
#   'bank_id': '2797724 ',
#   'bank_location': 'PORTSMOUTH, VA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,624 ',
#   'domestic_assets': '12,624 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '43 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANNER BK/BANNER CORP ',
#   'national_rank': '109 ',
#   'bank_id': '352772 ',
#   'bank_location': 'WALLA WALLA, WA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,491 ',
#   'domestic_assets': '12,491 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '172 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'GREAT WESTERN BK/GREAT WESTERN BC ',
#   'national_rank': '110 ',
#   'bank_id': '131650 ',
#   'bank_location': 'SIOUX FALLS, SD ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,385 ',
#   'domestic_assets': '12,385 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '175 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'EASTERN BK/EASTERN BK CORP ',
#   'national_rank': '111 ',
#   'bank_id': '128904 ',
#   'bank_location': 'BOSTON, MA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,341 ',
#   'domestic_assets': '12,341 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '88 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COMENITY BK/ ',
#   'national_rank': '112 ',
#   'bank_id': '1391778 ',
#   'bank_location': 'WILMINGTON, DE ',
#   'charter': 'SNM ',
#   'consolidated_assets': '12,144 ',
#   'domestic_assets': '12,144 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CUSTOMERS BK/CUSTOMERS BC ',
#   'national_rank': '113 ',
#   'bank_id': '2354985 ',
#   'bank_location': 'PHOENIXVILLE, PA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '12,010 ',
#   'domestic_assets': '12,010 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '14 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ROCKLAND TC/INDEPENDENT BC ',
#   'national_rank': '114 ',
#   'bank_id': '613008 ',
#   'bank_location': 'ROCKLAND, MA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '11,987 ',
#   'domestic_assets': '11,987 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '97 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PACIFIC PREMIER BK/PACIFIC PREMIER BC ',
#   'national_rank': '115 ',
#   'bank_id': '431172 ',
#   'bank_location': 'IRVINE, CA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '11,975 ',
#   'domestic_assets': '11,975 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '40 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PLAINSCAPITAL BK/DIAMOND HTH STOCK CO GP LLC ',
#   'national_rank': '116 ',
#   'bank_id': '637451 ',
#   'bank_location': 'DALLAS, TX ',
#   'charter': 'SMB ',
#   'consolidated_assets': '11,882 ',
#   'domestic_assets': '11,882 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '88 ',
#   'no_domestic_branches': '62 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COMMUNITY BK NA/COMMUNITY BK SYS ',
#   'national_rank': '117 ',
#   'bank_id': '202907 ',
#   'bank_location': 'CANTON, NY ',
#   'charter': 'NAT ',
#   'consolidated_assets': '11,614 ',
#   'domestic_assets': '11,614 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '89 ',
#   'no_domestic_branches': '230 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIZENS BUS BK/CVB FC ',
#   'national_rank': '118 ',
#   'bank_id': '933966 ',
#   'bank_location': 'ONTARIO, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '11,603 ',
#   'domestic_assets': '11,603 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '89 ',
#   'no_domestic_branches': '57 ',
# ...
#   'no_domestic_branches': '11 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIZENS BK OF KY/CITIZENS NAT CORP ',
#   'national_rank': '959 ',
#   'bank_id': '495419 ',
#   'bank_location': 'PAINTSVILLE, KY ',
#   'charter': 'SMB ',
#   'consolidated_assets': '659 ',
#   'domestic_assets': '659 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '11 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'AMERICAN ST B&TC/AMERICAN ST BSHRS ',
#   'national_rank': '960 ',
#   'bank_id': '2957014 ',
#   'bank_location': 'WICHITA, KS ',
#   'charter': 'SMB ',
#   'consolidated_assets': '658 ',
#   'domestic_assets': '658 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '15 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': '1ST FNCL BK USA/ ',
#   'national_rank': '961 ',
#   'bank_id': '526452 ',
#   'bank_location': 'DAKOTA DUNES, SD ',
#   'charter': 'SNM ',
#   'consolidated_assets': '658 ',
#   'domestic_assets': '658 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '1 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BANCO DO BRASIL AMERS/ ',
#   'national_rank': '962 ',
#   'bank_id': '110936 ',
#   'bank_location': 'MIAMI, FL ',
#   'charter': 'SNM ',
#   'consolidated_assets': '658 ',
#   'domestic_assets': '658 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '4 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FINANCIAL FED BK/FINANCIAL FEDCORP ',
#   'national_rank': '963 ',
#   'bank_id': '590976 ',
#   'bank_location': 'MEMPHIS, TN ',
#   'charter': 'SMB ',
#   'consolidated_assets': '658 ',
#   'domestic_assets': '658 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '0 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'HAWAII NB/HAWAII NAT BSHRS ',
#   'national_rank': '964 ',
#   'bank_id': '915065 ',
#   'bank_location': 'HONOLULU, HI ',
#   'charter': 'NAT ',
#   'consolidated_assets': '657 ',
#   'domestic_assets': '657 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '13 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'JEFFERSON BK OF MO/CENTRAL BANCOMPANY INC ',
#   'national_rank': '965 ',
#   'bank_id': '854454 ',
#   'bank_location': 'JEFFERSON CITY, MO ',
#   'charter': 'SMB ',
#   'consolidated_assets': '656 ',
#   'domestic_assets': '656 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '3 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'ONEUNITED BK/ ',
#   'national_rank': '966 ',
#   'bank_id': '935308 ',
#   'bank_location': 'BOSTON, MA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '656 ',
#   'domestic_assets': '656 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '8 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'MARINE BK/MARINE BC ',
#   'national_rank': '967 ',
#   'bank_id': '258445 ',
#   'bank_location': 'SPRINGFIELD, IL ',
#   'charter': 'SNM ',
#   'consolidated_assets': '656 ',
#   'domestic_assets': '656 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '10 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PEOPLES B&TC/PBT BSHRS ',
#   'national_rank': '968 ',
#   'bank_id': '153353 ',
#   'bank_location': 'MCPHERSON, KS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '655 ',
#   'domestic_assets': '655 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '12 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST SECURITY BK/SECURITY CAPITAL CORP ',
#   'national_rank': '969 ',
#   'bank_id': '718145 ',
#   'bank_location': 'BATESVILLE, MS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '652 ',
#   'domestic_assets': '652 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '16 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'JONESTOWN B&TC/ ',
#   'national_rank': '970 ',
#   'bank_id': '653611 ',
#   'bank_location': 'JONESTOWN, PA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '652 ',
#   'domestic_assets': '652 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '12 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WEST AL B&TC/WEST AL CAP CORP ',
#   'national_rank': '971 ',
#   'bank_id': '501132 ',
#   'bank_location': 'REFORM, AL ',
#   'charter': 'SNM ',
#   'consolidated_assets': '651 ',
#   'domestic_assets': '651 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '13 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'UNITED PRAIRIE BK/FARMERS ST CORP ',
#   'national_rank': '972 ',
#   'bank_id': '712059 ',
#   'bank_location': 'MOUNTAIN LAKE, MN ',
#   'charter': 'SNM ',
#   'consolidated_assets': '650 ',
#   'domestic_assets': '650 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '11 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PORT WASHINGTON ST BK/PORT BSHRS ',
#   'national_rank': '973 ',
#   'bank_id': '937740 ',
#   'bank_location': 'PORT WASHINGTON, WI ',
#   'charter': 'SNM ',
#   'consolidated_assets': '647 ',
#   'domestic_assets': '647 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'DIAMOND BK/BAINUM BANCORP ',
#   'national_rank': '974 ',
#   'bank_id': '27847 ',
#   'bank_location': 'MURFREESBORO, AR ',
#   'charter': 'SMB ',
#   'consolidated_assets': '647 ',
#   'domestic_assets': '647 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '15 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': '1ST CAP BK/ ',
#   'national_rank': '975 ',
#   'bank_id': '3594797 ',
#   'bank_location': 'SALINAS, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '646 ',
#   'domestic_assets': '646 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '4 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PEOPLES BK/PEOPLES FC ',
#   'national_rank': '976 ',
#   'bank_id': '870539 ',
#   'bank_location': 'BILOXI, MS ',
#   'charter': 'SNM ',
#   'consolidated_assets': '644 ',
#   'domestic_assets': '644 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '17 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIZENS BK/AMADOR BSHRS ',
#   'national_rank': '977 ',
#   'bank_id': '1016857 ',
#   'bank_location': 'LAS CRUCES, NM ',
#   'charter': 'SNM ',
#   'consolidated_assets': '641 ',
#   'domestic_assets': '641 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PILOT GROVE SVG BK/PILOT GROVE SVGS BK ESOP ',
#   'national_rank': '978 ',
#   'bank_id': '585749 ',
#   'bank_location': 'PILOT GROVE, IA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '641 ',
#   'domestic_assets': '641 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '13 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CORE BK/DS HC ',
#   'national_rank': '979 ',
#   'bank_id': '976552 ',
#   'bank_location': 'OMAHA, NE ',
#   'charter': 'SNM ',
#   'consolidated_assets': '640 ',
#   'domestic_assets': '640 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PIONEER BK/CITIZENS BK GROUP ',
#   'national_rank': '980 ',
#   'bank_id': '920854 ',
#   'bank_location': 'MAPLETON, MN ',
#   'charter': 'SMB ',
#   'consolidated_assets': '640 ',
#   'domestic_assets': '640 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'HOMETOWN BK NA/MOODY BSHRS ',
#   'national_rank': '981 ',
#   'bank_id': '393953 ',
#   'bank_location': 'GALVESTON, TX ',
#   'charter': 'NAT ',
#   'consolidated_assets': '639 ',
#   'domestic_assets': '639 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SPIRITBANK/SPIRIT BC ',
#   'national_rank': '982 ',
#   'bank_id': '142955 ',
#   'bank_location': 'TULSA, OK ',
#   'charter': 'SNM ',
#   'consolidated_assets': '638 ',
#   'domestic_assets': '638 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BAC CMNTY BK/BAC FNCL ',
#   'national_rank': '983 ',
#   'bank_id': '5461 ',
#   'bank_location': 'STOCKTON, CA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '637 ',
#   'domestic_assets': '637 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '10 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'OXFORD B&T/OXFORD FC ',
#   'national_rank': '984 ',
#   'bank_id': '647432 ',
#   'bank_location': 'OAK BROOK, IL ',
#   'charter': 'SNM ',
#   'consolidated_assets': '637 ',
#   'domestic_assets': '637 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'COMMERCEWEST BK/ ',
#   'national_rank': '985 ',
#   'bank_id': '3052813 ',
#   'bank_location': 'IRVINE, CA ',
#   'charter': 'SMB ',
#   'consolidated_assets': '637 ',
#   'domestic_assets': '637 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '1 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'WEST MI CMNTY BK/NORTHSTAR FNCL GRP ',
#   'national_rank': '986 ',
#   'bank_id': '715340 ',
#   'bank_location': 'HUDSONVILLE, MI ',
#   'charter': 'SMB ',
#   'consolidated_assets': '635 ',
#   'domestic_assets': '635 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST NB/BASTROP BSHRS ',
#   'national_rank': '987 ',
#   'bank_id': '18050 ',
#   'bank_location': 'BASTROP, TX ',
#   'charter': 'NAT ',
#   'consolidated_assets': '635 ',
#   'domestic_assets': '635 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '5 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST NB MI/FIRST NAT BC ',
#   'national_rank': '988 ',
#   'bank_id': '3404467 ',
#   'bank_location': 'KALAMAZOO, MI ',
#   'charter': 'NAT ',
#   'consolidated_assets': '635 ',
#   'domestic_assets': '635 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '4 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST NB/FIRST GRANBURY BC ',
#   'national_rank': '989 ',
#   'bank_id': '329952 ',
#   'bank_location': 'GRANBURY, TX ',
#   'charter': 'NAT ',
#   'consolidated_assets': '634 ',
#   'domestic_assets': '634 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CITIZENS BK/ ',
#   'national_rank': '990 ',
#   'bank_id': '126834 ',
#   'bank_location': 'CARTHAGE, TN ',
#   'charter': 'SNM ',
#   'consolidated_assets': '634 ',
#   'domestic_assets': '634 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'SUTTON BK/SUTTON BSHRS ',
#   'national_rank': '991 ',
#   'bank_id': '110413 ',
#   'bank_location': 'ATTICA, OH ',
#   'charter': 'SNM ',
#   'consolidated_assets': '634 ',
#   'domestic_assets': '634 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '7 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'LIBERTY NAT BK/BOE BSHRS ',
#   'national_rank': '992 ',
#   'bank_id': '68756 ',
#   'bank_location': 'LAWTON, OK ',
#   'charter': 'NAT ',
#   'consolidated_assets': '633 ',
#   'domestic_assets': '633 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'CORNHUSKER BK/CORNHUSKER GROWTH CORP ',
#   'national_rank': '993 ',
#   'bank_id': '544652 ',
#   'bank_location': 'LINCOLN, NE ',
#   'charter': 'SMB ',
#   'consolidated_assets': '632 ',
#   'domestic_assets': '632 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '9 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'FIRST CMNTY BK OF TN/FIRST CMNTY BC ',
#   'national_rank': '994 ',
#   'bank_id': '1188772 ',
#   'bank_location': 'SHELBYVILLE, TN ',
#   'charter': 'SNM ',
#   'consolidated_assets': '632 ',
#   'domestic_assets': '632 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '4 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'OREGON CMNTY BK/BOSSHARD FNCL GRP ',
#   'national_rank': '995 ',
#   'bank_id': '247140 ',
#   'bank_location': 'OREGON, WI ',
#   'charter': 'SMB ',
#   'consolidated_assets': '631 ',
#   'domestic_assets': '631 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '5 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'BAKER BOYER NB/BAKER BOYER BC ',
#   'national_rank': '996 ',
#   'bank_id': '69678 ',
#   'bank_location': 'WALLA WALLA, WA ',
#   'charter': 'NAT ',
#   'consolidated_assets': '631 ',
#   'domestic_assets': '631 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '6 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'TEXAS SCTY BK/TEXAS SCTY BSHRS ',
#   'national_rank': '997 ',
#   'bank_id': '3619216 ',
#   'bank_location': 'DALLAS, TX ',
#   'charter': 'SNM ',
#   'consolidated_assets': '629 ',
#   'domestic_assets': '629 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '3 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  {'bank_holding_name': 'PEOPLES BK/PEOPLES BC ',
#   'national_rank': '998 ',
#   'bank_id': '998844 ',
#   'bank_location': 'ROCK VALLEY, IA ',
#   'charter': 'SNM ',
#   'consolidated_assets': '629 ',
#   'domestic_assets': '629 ',
#   'pct_domestic_assets': '100 ',
#   'pct_cumulative_assets': '98 ',
#   'no_domestic_branches': '8 ',
#   'no_foreign_branches': '0 ',
#   'ibf': 'N ',
#   'as_of_dt': '20200331'},
#  ...]

# %% [markdown]
# ## 1.e. Convert to DataFrame and Dump to Disk

# %%
# Convert to DataFrame
df = pd.DataFrame(commercial_data)

# Let's also create columns for the reporting year & month
df['as_of_year'] = df['as_of_dt'].apply(lambda x: x[0:4])
df['as_of_mth'] = df['as_of_dt'].apply(lambda x: x[4:6])
df['as_of_period'] = df['as_of_mth'] + '-' + df['as_of_year']

df.head()
# Out:
#                            bank_holding_name national_rank  bank_id  \
# 0  JPMORGAN CHASE BK NA/JPMORGAN CHASE & CO             1   852218
# 1         BANK OF AMER NA/BANK OF AMER CORP             2   480228
# 2        WELLS FARGO BK NA/WELLS FARGO & CO             3   451965
# 3                     CITIBANK NA/CITIGROUP             4   476810
# 4                          U S BK NA/U S BC             5   504713
#
#       bank_location charter consolidated_assets domestic_assets  \
# 0     COLUMBUS, OH     NAT           2,690,959       1,990,017
# 1    CHARLOTTE, NC     NAT           2,031,940       1,925,005
# 2  SIOUX FALLS, SD     NAT           1,763,696       1,715,842
# 3  SIOUX FALLS, SD     NAT           1,632,405         971,079
# 4   CINCINNATI, OH     NAT             533,129         522,496
#
#   pct_domestic_assets pct_cumulative_assets no_domestic_branches  \
# 0                 74                    15                4,971
# 1                 95                    26                4,239
# 2                 97                    35                5,416
# 3                 59                    44                  697
# 4                 98                    47                2,832
#
#   no_foreign_branches ibf  as_of_dt as_of_year as_of_mth as_of_period
# 0                 33   Y   20200331       2020        03      03-2020
# 1                 26   Y   20200331       2020        03      03-2020
# 2                 11   Y   20200331       2020        03      03-2020
# 3                157   Y   20200331       2020        03      03-2020
# 4                  1   N   20200331       2020        03      03-2020

# %%
# Explore some quick stats for the health of the data
df.describe()
# Out:
#                            bank_holding_name national_rank  bank_id  \
# count                                  98354         98354    98354
# unique                                  4331          1854     3182
# top     BREMER BK NA/OTTO BREMER FOUNDATION          1036   591320
# freq                                     276            62      189
#
#         bank_location charter consolidated_assets domestic_assets  \
# count           98354   98354               98354           98354
# unique           2156       3               11269           11274
# top     NEW YORK, NY     SNM                   .               .
# freq             1413   55446                 575             575
#
#        pct_domestic_assets pct_cumulative_assets no_domestic_branches  \
# count                98354                 98354                98354
# unique                  57                    74                 1282
# top                   100                    99                    6
# freq                 96009                 18513                 6784
#
#        no_foreign_branches    ibf  as_of_dt
# count                98354  98354     98354
# unique                  80      3        56
# top                     0      N   20200331
# freq                 95983  95556      1863

# %%
# Dump to disk for storage and next stage in the project
df.to_excel(data_file, index=False)
